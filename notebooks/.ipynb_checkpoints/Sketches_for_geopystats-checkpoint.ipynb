# %%
# Load Biospytial modules and etc.
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()
import pandas as pd
import numpy as np

# %% [markdown]
# # Sketches for automating spatial models
# This notebook is for designing the tool box and methods for fitting spatial data.
# I´m using the library Geopystats (before spystats)

# %% [markdown]
# ## Requirements
# * Given a dataset in Geopandas dataframe, create the Variogram object.
# And read from the file the variogram data

# %%
from external_plugins.spystats import tools
# %run ../HEC_runs/fit_fia_logbiomass_logspp_GLS.py
# Out:
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/pylabtools.py:168: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   safe_execfile(fname,*where,**kw)
# INFO:__main__:Reading the empirical Variogram file

# %% [markdown]
# The object new_data has been reprojected to Alberts and a linear model have been fitted with residuals stored as *residuals*

# %%
new_data.residuals[:10]
# Out:
# 0    0.390705
# 1   -0.499146
# 2   -0.793889
# 3   -0.185936
# 4    0.411008
# 5    0.294243
# 6   -0.399424
# 7    0.834632
# 8    0.339474
# 9   -0.152521
# Name: residuals, dtype: float64

# %% [markdown]
# ## The empirical variogram
# The empirical variogram has been calculated already using the HEC. A variogram object has been created which takes the values from the previously calculated in HEC

# %%
gvg.plot(refresh=False,legend=False,percentage_trunked=20)
plt.title("Semivariogram of residuals $log(Biomass) ~ log(SppR)$")

# %% [markdown]
# Now that the empirical variogram has been created we need to use a valid theoretical variogram model to fit it.
# The models ares in *spystats.tools*

# %%
from external_plugins.spystats import tools
hx = np.linspace(0,100000,100)
expmod = tools.exponentialVariogram(hx,sill=100,nugget=10,range_a=100000)
gausmod = tools.gaussianVariogram(hx,sill=100,nugget=10,range_a=10000)
plt.plot(hx,expmod)
plt.plot(hx,gausmod)

# %%
# Function for fitting a theoretical variogram

def fitVariogram(empirical_variogram,model,parameter_set):
    """
    Fits a valid model (tools.model) to the empirical variogram object as base.
    
    Parameters:
        empirical_variogram : (Object) an instance from the Variogram Class
        model : a Valid model (function)
        parameter_set : a tuple containing the parameters to be fitted from the model
    
    Returns:
        A function with the optimized parameters.
    """
    from scipy.optimize import curve_fit
    n_p = len(parameter_set)
    try:
        best_params, covar_model = curve_fit(model, xdata=empirical_variogram.lags.values, ydata=empirical_variogram.variogram.values, p0=parameter_set)
    except:
        logger.error("Model selected doesn´t support more than 3 parametes")
        
    #s = 0.345
    #r = 50000.0
    #nugget = 0.33
    #kappa = 0.5
    init_vals = [s,r,nugget] # for [amp, cen, wid]
    init_matern = [s,r,nugget,kappa]
    #bg, covar_gaussian = curve_fit(gaussianVariogram, xdata=emp_var_log_log.lags.values, ydata=emp_var_log_log.variogram.values, p0=init_vals)
    best_params, covar_model = curve_fit(model, xdata=emp_var_log_log.lags.values, ydata=emp_var_log_log.variogram.values, p0=init_matern)
    #MaternVariogram(h,range_a,nugget=40,sill=100,kappa=0.5)
    #vdata = gvg.envelope.dropna()
    ## The best parameters asre:
    #gau_var = tools.gaussianVariogram(hx,bg[0],bg[1],bg[2])
    gau_var = MaternVariogram(hx,bg[0],bg[1],bg[2],bg[3])
    tools.
