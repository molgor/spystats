# %%
# %matplotlib inline
import sys
sys.path.append('/apps')
import django
django.setup()
from drivers.graph_models import TreeNode, Order, Family, graph, pickNode
from drivers.tree_builder import TreeNeo
from traversals.strategies import sumTrees, UniformRandomSampleForest
import pandas as pd
import matplotlib.pyplot as plt
## Use the ggplot style
plt.style.use('ggplot')

# %% [markdown]
# ## Let's start by pick a Family Node, e.g. The Bees in Mexico.

# %%
bees = pickNode(Family,name="Apidae")

# %%
# Extract the cells
bcells  = list(bees.cells)

# %%
len(bcells)
# Out:
# 1118

# %% [markdown]
# ### Get neighbours from the selected cells, reduce into a single list and then remove the duplicates (casting to set)

# %%
### In the form of a anonymous function
getNeighbours = lambda cells : list(set(reduce(lambda a,b : a+b , map(lambda cell : cell.getNeighbours(),cells))))

# %%
## Get neighbours in order 2
neighbour_cells = getNeighbours(getNeighbours(bcells))

# %% [markdown]
# ## Here we create the response variable $y \sim Bin(p,k)$

# %%
# %time y = [1 if bee in bcells else 0 for bee in neighbour_cells]
# Out:
# CPU times: user 1min 10s, sys: 212 ms, total: 1min 10s
# Wall time: 1min 10s

# %% [markdown]
# ### We can extract the coordinates of neighbour cells and try to fit a model without covariates

# %%
# %time coords = map(lambda c : (c.centroid.x,c.centroid.y) , ccs)
# Out:
# CPU times: user 1.48 s, sys: 0 ns, total: 1.48 s
# Wall time: 1.47 s

# %%
lon,lat = zip(*coords)

# %%
X = pd.DataFrame([lon,lat])
Y = pd.DataFrame(y)

# %%
plt.figure(figsize=(17,11))
plt.scatter(lon,lat,c=Y)

# %%
# Import GPFlow
import GPflow as gf
k = gf.kernels.Matern12(2, lengthscales=1, active_dims = [0,1] )
model = gf.gpr.GPR(X.as_matrix(),Y.as_matrix().reshape(len(Y),1).astype(float),k)

# %%
len(X)
# %time model.optimize()
# Out:
# InvalidArgumentErrorTraceback (most recent call last)
# <ipython-input-87-57c35e6a9e1b> in <module>()
#       1 len(X)
# ----> 2 get_ipython().magic(u'time model.optimize()')
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1174         if mode=='eval':
#    1175             st = clock2()
# -> 1176             out = eval(code, glob, local_ns)
#    1177             end = clock2()
#    1178         else:
#
# <timed eval> in <module>()
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/model.pyc in optimize(self, method, tol, callback, maxiter, **kw)
#     221
#     222         if type(method) is str:
# --> 223             return self._optimize_np(method, tol, callback, maxiter, **kw)
#     224         else:
#     225             return self._optimize_tf(method, callback, maxiter, **kw)
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/model.pyc in _optimize_np(self, method, tol, callback, maxiter, **kw)
#     306                               tol=tol,
#     307                               callback=callback,
# --> 308                               options=options)
#     309         except KeyboardInterrupt:
#     310             print("Caught KeyboardInterrupt, setting \
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/scipy/optimize/_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     445     elif meth == 'l-bfgs-b':
#     446         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 447                                 callback=callback, **options)
#     448     elif meth == 'tnc':
#     449         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     328                 # minimization routine wants f and g at the current x
#     329                 # Overwrite f and g:
# --> 330                 f, g = func_and_grad(x)
#     331         elif task_str.startswith(b'NEW_X'):
#     332             # new iteration
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     276     else:
#     277         def func_and_grad(x):
# --> 278             f = fun(x, *args)
#     279             g = jac(x, *args)
#     280             return f, g
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     287     def function_wrapper(*wrapper_args):
#     288         ncalls[0] += 1
# --> 289         return function(*(wrapper_args + args))
#     290
#     291     return ncalls, function_wrapper
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/model.pyc in __call__(self, x)
#      41
#      42     def __call__(self, x):
# ---> 43         f, g = self._objective(x)
#      44         g_is_fin = np.isfinite(g)
#      45         if np.all(g_is_fin):
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/model.pyc in obj(x)
#     159             self.update_feed_dict(self._feed_dict_keys, feed_dict)
#     160             f, g = self._session.run([self._minusF, self._minusG],
# --> 161                                      feed_dict=feed_dict)
#     162             return f.astype(np.float64), g.astype(np.float64)
#     163
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1338         except KeyError:
#    1339           pass
# -> 1340       raise type(e)(node_def, op, message)
#    1341
#    1342   def _extend_graph(self):
#
# InvalidArgumentError: Incompatible shapes: [9703,1] vs. [2,1]
# 	 [[Node: name.build_likelihood/sub = Sub[T=DT_DOUBLE, _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_Y_0_2, name.build_likelihood/zeros)]]
#
# Caused by op u'name.build_likelihood/sub', defined at:
#   File "/opt/conda/envs/biospytial/lib/python2.7/runpy.py", line 162, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/opt/conda/envs/biospytial/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 403, in start
#     ioloop.IOLoop.instance().start()
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/tornado/ioloop.py", line 883, in start
#     handler_func(fd_obj, events)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 260, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 212, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 370, in execute_request
#     user_expressions, allow_stdin)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 175, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2827, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-87-57c35e6a9e1b>", line 2, in <module>
#     get_ipython().magic(u'time model.optimize()')
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2158, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2079, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-59>", line 2, in time
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/magic.py", line 188, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/IPython/core/magics/execution.py", line 1176, in time
#     out = eval(code, glob, local_ns)
#   File "<timed eval>", line 1, in <module>
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/model.py", line 223, in optimize
#     return self._optimize_np(method, tol, callback, maxiter, **kw)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/model.py", line 284, in _optimize_np
#     self._compile()
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/model.py", line 133, in _compile
#     f = self.build_likelihood() + self.build_prior()
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/scoping.py", line 43, in runnable
#     return f(*args, **kwargs)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/gpr.py", line 63, in build_likelihood
#     return multivariate_normal(self.Y, m, L)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/GPflow-0.3.8-py2.7.egg/GPflow/densities.py", line 80, in multivariate_normal
#     d = x - mu
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/ops/math_ops.py", line 865, in binary_op_wrapper
#     return func(x, y, name=name)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/ops/gen_math_ops.py", line 2629, in _sub
#     result = _op_def_lib.apply_op("Sub", x=x, y=y, name=name)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2630, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/opt/conda/envs/biospytial/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1204, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Incompatible shapes: [9703,1] vs. [2,1]
# 	 [[Node: name.build_likelihood/sub = Sub[T=DT_DOUBLE, _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_Y_0_2, name.build_likelihood/zeros)]]

# %%
import tensorflow as tf
import GPflow as gf
import pandas as pd

# %%
import pandas as pd
run traversals/tests.py
k = gf.kernels.Matern12(2, lengthscales=1, active_dims = [3,4])
X = pd.concat((rd[['MeanTemperature_mean','Precipitation_mean','WindSpeed_mean']],s[['Longitude','Latitude']]),axis=1)
Y = rd['Elevation_mean']
mx = X.as_matrix()
my = Y.as_matrix().reshape(16,1)
meanf = gf.mean_functions.Linear(np.ones((5,1)), np.ones(1))
m = gf.gpr.GPR(mx,my,k,mean_function=meanf)
m.optimize()
print(m)
# Out:
#   File "<ipython-input-5-a02cd7e2745b>", line 4
#     run traversals/tests.py
#                  ^
# SyntaxError: invalid syntax

# %%
X = pd.concat((rd[['MeanTemperature_mean','Precipitation_mean','WindSpeed_mean']],s[['Longitude','Latitude']]),axis=1)
# Out:
# array([[ 1,  4,  1],
#        [ 2, 55,  2]])

# %%
cc = tf.reduce_sum(x,axis=1)
print(session.run(cc))
cc = tf.reduce_sum(x,axis=0)
print(session.run(cc))
cc = tf.reduce_sum(x,axis=[0,1])
print(session.run(cc))
# Out:
# [ 6 59]
# [ 3 59  3]
# 65

# %%
domain_of_x = tf.range(0,10,delta=0.03)
session.run(domain_of_x)
# Out:
# array([ 0.        ,  0.03      ,  0.06      ,  0.09      ,  0.12      ,
#         0.14999999,  0.17999999,  0.20999999,  0.23999999,  0.26999998,
#         0.29999998,  0.32999998,  0.35999998,  0.38999999,  0.41999999,
#         0.44999999,  0.47999999,  0.50999999,  0.53999996,  0.56999993,
#         0.5999999 ,  0.62999988,  0.65999985,  0.68999982,  0.71999979,
#         0.74999976,  0.77999973,  0.8099997 ,  0.83999968,  0.86999965,
#         0.89999962,  0.92999959,  0.95999956,  0.98999953,  1.0199995 ,
#         1.04999948,  1.07999945,  1.10999942,  1.13999939,  1.16999936,
#         1.19999933,  1.2299993 ,  1.25999928,  1.28999925,  1.31999922,
#         1.34999919,  1.37999916,  1.40999913,  1.4399991 ,  1.46999907,
#         1.49999905,  1.52999902,  1.55999899,  1.58999896,  1.61999893,
#         1.6499989 ,  1.67999887,  1.70999885,  1.73999882,  1.76999879,
#         1.79999876,  1.82999873,  1.8599987 ,  1.88999867,  1.91999865,
#         1.94999862,  1.97999859,  2.00999856,  2.03999853,  2.0699985 ,
#         2.09999847,  2.12999845,  2.15999842,  2.18999839,  2.21999836,
#         2.24999833,  2.2799983 ,  2.30999827,  2.33999825,  2.36999822,
#         2.39999819,  2.42999816,  2.45999813,  2.4899981 ,  2.51999807,
#         2.54999804,  2.57999802,  2.60999799,  2.63999796,  2.66999793,
#         2.6999979 ,  2.72999787,  2.75999784,  2.78999782,  2.81999779,
#         2.84999776,  2.87999773,  2.9099977 ,  2.93999767,  2.96999764,
#         2.99999762,  3.02999759,  3.05999756,  3.08999753,  3.1199975 ,
#         3.14999747,  3.17999744,  3.20999742,  3.23999739,  3.26999736,
#         3.29999733,  3.3299973 ,  3.35999727,  3.38999724,  3.41999722,
#         3.44999719,  3.47999716,  3.50999713,  3.5399971 ,  3.56999707,
#         3.59999704,  3.62999701,  3.65999699,  3.68999696,  3.71999693,
#         3.7499969 ,  3.77999687,  3.80999684,  3.83999681,  3.86999679,
#         3.89999676,  3.92999673,  3.9599967 ,  3.98999667,  4.01999664,
#         4.04999685,  4.07999706,  4.10999727,  4.13999748,  4.16999769,
#         4.1999979 ,  4.22999811,  4.25999832,  4.28999853,  4.31999874,
#         4.34999895,  4.37999916,  4.40999937,  4.43999958,  4.46999979,
#         4.5       ,  4.53000021,  4.56000042,  4.59000063,  4.62000084,
